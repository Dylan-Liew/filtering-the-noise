# %%
import json
import pandas as pd
from dotenv import dotenv_values
from sqlalchemy import create_engine

config = dotenv_values()
engine = create_engine(config["DB_URI"])


def parse_json_string(json_str):
    """Parse JSON string back to Python object."""
    if pd.isna(json_str) or json_str is None:
        return None
    try:
        return json.loads(json_str)
    except (json.JSONDecodeError, TypeError):
        return json_str  # Return as-is if not valid JSON

# Construct SQL query
query = f"SELECT * FROM data"
# Load data from database
df = pd.read_sql(query, con=engine, index_col=None)

print(f"Successfully loaded {len(df)} rows from 'data' table")

# Convert JSON string columns back to Python objects
if 'category' in df.columns:
    df['category'] = df['category'].apply(parse_json_string)
if 'images' in df.columns:
    df['images'] = df['images'].apply(parse_json_string)

df.info()
# Out:
# Successfully loaded 1000000 rows from 'data' table
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   review_time           1000000 non-null  int64
#  1   rating                1000000 non-null  int64
#  2   uuid                  1000000 non-null  object
#  3   has_image             1000000 non-null  bool
#  4   images                1000000 non-null  object
#  5   review_cleaned        1000000 non-null  object
#  6   business_description  513735 non-null   object
#  7   category              999763 non-null   object
# dtypes: bool(1), int64(2), object(5)
# memory usage: 54.4+ MB

# %%
df.head(n=5)
# Out:
#      review_time  rating                                  uuid  has_image  \
# 0  1570668707682       3  11dd1bf5-0e05-4f58-b24e-f9e05a6937a3      False
# 1  1549240941555       4  77a38301-8c7f-491e-adaf-8987f1d9b11f      False
# 2  1538599650146       5  8bf3b257-3636-46ec-a420-905ddeeb12ec      False
# 3  1543200396651       1  517cdc49-418b-4bae-8d91-3df5279d380e      False
# 4  1472363463561       3  61f29b12-b632-473d-97c4-341b35e3ac4b      False
#
#   images                                     review_cleaned  \
# 0     []
# 1     []
# 2     []  YUM!!!! Definitely beat the twice-as-expensive...
# 3     []  Room was not cleaned very well. Found skittles...
# 4     []
#
#                                 business_description  \
# 0                                               None
# 1  Fast, casual seafood restaurant chain serving ...
# 2  Circa-1950 fast-food chain for counter-serve b...
# 3  Casual lodging with an outdoor pool, plus free...
# 4  Simple chain spot offering American diner fare...
#
#                                             category
# 0                                    [Auto painting]
# 1  [Seafood restaurant, American restaurant, Fami...
# 2  [Restaurant, Breakfast restaurant, Chicken res...
# 3           [Hotel, Business center, Indoor lodging]
# 4  [Breakfast restaurant, American restaurant, Di...

# %%
df.sample(n=10)[['has_image', 'images', 'review_cleaned', 'business_description', 'category']]
# Out:
#         has_image images                                     review_cleaned  \
# 260445      False     []                      My favorite store in Cullman.
# 581381      False     []
# 958786      False     []
# 876907      False     []
# 936339      False     []  Super delicious pizza and great fresh salad :t...
# 931968      False     []                            Self check out is great
# 973113      False     []
# 168682      False     []  Remodle was well worth it but the katchup pack...
# 703126      False     []
# 525872      False     []  Best sirloin steak and cesar salad. Will be ba...
#
#                                      business_description  \
# 260445                                               None
# 581381                                               None
# 958786  Fast-food chain serving fried chicken, big bur...
# 876907  This museum about the people & events surround...
# 936339  Pizzeria chain offering an array of craft beer...
# 931968                                               None
# 973113  Chain featuring a range of pets, supplies & fo...
# 168682  Classic, long-running fast-food chain known fo...
# 703126                                               None
# 525872  Lively chain steakhouse serving American fare ...
#
#                                                  category
# 260445                             [Sporting goods store]
# 581381                               [Mexican restaurant]
# 958786       [Fast food restaurant, Hamburger restaurant]
# 876907       [History museum, Museum, Tourist attraction]
# 936339                                 [Pizza restaurant]
# 931968  [Department store, Clothing store, Craft store...
# 973113  [Pet supply store, Pet adoption service, Pet g...
# 168682  [Fast food restaurant, Breakfast restaurant, C...
# 703126                                     [Honda dealer]
# 525872  [Steak house, American restaurant, New America...

# %%
df.sample(n=10)[['category', "review_cleaned", "review_cleaned"]]
# Out:
#                                                  category  \
# 843462                                        [Toy store]
# 884205  [Italian restaurant, Caterer, Family restauran...
# 479749           [Hotel, Business center, Indoor lodging]
# 418202  [Toyota dealer, Auto parts store, Auto repair ...
# 876167  [Fabric store, Baking supply store, Bead store...
# 243305  [Department store, Baby store, Clothing store,...
# 487822  [Outdoor sports store, Clothing store, Exercis...
# 429553  [Furniture store, Glassware store, Kitchen sup...
# 667626                                  [Ophthalmologist]
# 307556  [American restaurant, Mexican restaurant, Rest...
#
#                                            review_cleaned  \
# 843462
# 884205  10 adults & 1 child. The service was quick in ...
# 479749  Easy acces to highway. Friendly staff. Ample p...
# 418202  Satisfied with the good customer service. My c...
# 876167
# 243305  This store is very well kept and clean. The wh...
# 487822
# 429553
# 667626  Dr. Vick provided a clear diagnosis and option...
# 307556  I enjoyed their variety of menu selections, I ...
#
#                                            review_cleaned
# 843462
# 884205  10 adults & 1 child. The service was quick in ...
# 479749  Easy acces to highway. Friendly staff. Ample p...
# 418202  Satisfied with the good customer service. My c...
# 876167
# 243305  This store is very well kept and clean. The wh...
# 487822
# 429553
# 667626  Dr. Vick provided a clear diagnosis and option...
# 307556  I enjoyed their variety of menu selections, I ...
